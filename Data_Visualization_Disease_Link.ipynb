# %% [markdown]
# <a href="https://colab.research.google.com/github/billchenxi/AI_platform/blob/master/Data_Visualization_Disease_Link.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Visualization -- Disease Link

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %matplotlib inline  
import pandas as pd
import numpy as np
import seaborn as sns

from matplotlib import pyplot as plt
from pprint import pprint

import plotly.graph_objects as go

def configure_plotly_browser_state():
  import IPython
  display(IPython.core.display.HTML('''
        <script src="/static/components/requirejs/require.js"></script>
        <script>
          requirejs.config({
            paths: {
              base: '/static/base',
              plotly: 'https://cdn.plot.ly/plotly-1.5.1.min.js?noext',
            },
          });
        </script>
        '''))

# %%
# list all the files
# !ls "/content/drive/Shared drives/FuseMachines - Juvena Therapeutics/Data/Disease-Links/"
# Out:
# cardiovascular_disease_links.csv  nutritional_metabolic_disease_links.csv
# endocrine_disease_links.csv	  skin_conncetiveTissue_disease_links.csv
# mental_disorder_links.csv	  vision_disease_links.csv
# myopathy_protein_links.csv	  wound_injury_disease_links.csv
# nervous_system_disease_links.csv

# %%
myopthy_path = "/content/drive/Shared drives/FuseMachines - Juvena Therapeutics/Data/Disease-Links/myopathy_protein_links.csv"
myopthy_data = pd.read_csv(myopthy_path, index_col=0)

# %% [markdown]
# ## Feature description

# %% [markdown]
# ### Cell Biology

# %%
myopthy_data_desc = myopthy_data.describe(include='all').transpose()
pd.set_option('display.max_rows', None)

myopthy_data_desc
# Out:
#                count unique  ...      75%          max
# Gene            1042    697  ...      NaN          NaN
# Gene_id         1042    NaN  ...  23228.5  1.07987e+08
# Gene_Full_Name  1042    690  ...      NaN          NaN
# DSI_g           1041    NaN  ...     0.69            1
# DPI_g           1041    NaN  ...     0.69        0.931
# pLI              984    NaN  ...  0.83659            1
# Disease         1042     36  ...      NaN          NaN
# Disease_id      1042     36  ...      NaN          NaN
# Type            1042      2  ...      NaN          NaN
# Score_gda       1042    NaN  ...     0.13          0.9
# EL_gda          1042      4  ...      NaN          NaN
# EI_gda           796    NaN  ...        1            1
# N_PMIDs         1042    NaN  ...        2          589
# N_SNPs_gda      1042    NaN  ...        0          142
# First_Ref        923    NaN  ...     2013         2018
# Last_Ref         923    NaN  ...     2015         2018
# ...

# %% [markdown]
# ## Numerical Histgram

# %%
plt.rcParams.update({'figure.max_open_warning': 0})
configure_plotly_browser_state()
numerica_data = myopthy_data.select_dtypes(include=np.number)
for col_name in numerica_data.columns:
     numerica_data.hist(col_name, bins=50)
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-1.5.1.min.js?noext',
#             },
#           });
#         </script>

# %%
pprint(list(cata_data.columns))
# Out:
# ['Gene',
#  'Gene_Full_Name',
#  'Disease',
#  'Disease_id',
#  'Type',
#  'EL_gda',
#  'Protein.Name',
#  'Interacts.with']

# %% [markdown]
# ## Categorical Histgram

# %%
# plt.rcParams.update({'figure.max_open_warning': 0})
# configure_plotly_browser_state()
# cata_data = myopthy_data.select_dtypes('object')
# for col_name in cata_data.columns:
#      cata_data[col_name].value_counts().plot(kind='bar')

# %%
pprint(list(cata_data.columns))
# Out:
# ['Gene',
#  'Gene_Full_Name',
#  'Disease',
#  'Disease_id',
#  'Type',
#  'EL_gda',
#  'Protein.Name',
#  'Interacts.with']
